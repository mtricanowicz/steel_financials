# %% [markdown]
# # SEC insights pipeline runner
#
# Thin interactive wrapper around `sec_pipeline.pipeline.run`. All logic lives in
# the package so it stays testable and reusable. Configure secrets in `core/.env`
# before running (see `core/README.md`).
#
# Steps performed per airline and period:
#
# 1. Resolve the CIK from SEC (with a static fallback).
# 2. Download the relevant 10-Q, 10-K, and 8-K filings inside the period window.
# 3. Parse each filing to clean text and split it into overlapping chunks.
# 4. Build a local Chroma collection and retrieve the most relevant passages.
# 5. Generate grouped markdown insights and write them to `data/generated/insights.json`.

# %%
from sec_pipeline import config
from sec_pipeline.pipeline import run

print("Embedding backend:", config.EMBEDDING_BACKEND)
print("Chat model:", config.OPENAI_CHAT_MODEL)
print("Output:", config.SUMMARIES_PATH)
# Out:
# Embedding backend: local
# Chat model: gpt-4o-mini
# Output: C:\Users\trica\OneDrive\Documents\GitHub Repos\steel_financials\steel-dashboard\data\generated\insights.json
# C:\Users\trica\OneDrive\Documents\GitHub Repos\steel_financials\steel-dashboard\core\sec_pipeline\summarize.py:97: SyntaxWarning: invalid escape sequence '\$'
#   End the response with a '### Wrap Up' heading followed by a single paragraph that summarizes the results and the positive and negative elements of forward guidance."""

# %%
AIRLINES = ["NUE", "STLD", "CLF", "CMC", "ATI", "CRS"]#, "X"]
YEARS = list(range(2026, 2027))
PERIODS = ["Q1"]#, "Q2", "Q3", "Q4", "FY"]

summaries = run(AIRLINES, YEARS, PERIODS, overwrite=False)
print("Airlines summarized:", list(summaries))
# Out:
# 2026-07-22 17:08:04,648 INFO No device provided, using cpu
# 2026-07-22 17:08:04,743 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:04,753 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/modules.json "HTTP/1.1 200 OK"
# 2026-07-22 17:08:04,822 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:04,839 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-07-22 17:08:04,857 INFO Loading SentenceTransformer model from sentence-transformers/all-MiniLM-L6-v2.
# 2026-07-22 17:08:04,889 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:04,914 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-07-22 17:08:04,965 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:04,972 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/README.md "HTTP/1.1 200 OK"
# 2026-07-22 17:08:05,079 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:05,102 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/modules.json "HTTP/1.1 200 OK"
# 2026-07-22 17:08:05,224 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/sentence_bert_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:05,236 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/sentence_bert_config.json "HTTP/1.1 200 OK"
# 2026-07-22 17:08:05,303 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-07-22 17:08:05,359 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:05,382 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config.json "HTTP/1.1 200 OK"
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3786.97it/s]
# 2026-07-22 17:08:05,521 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-22 17:08:05,572 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-22 17:08:05,620 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/video_preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-22 17:08:05,678 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-22 17:08:05,722 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:05,742 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-07-22 17:08:05,808 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:05,820 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config.json "HTTP/1.1 200 OK"
# 2026-07-22 17:08:05,873 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:05,888 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config.json "HTTP/1.1 200 OK"
# 2026-07-22 17:08:05,941 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:05,959 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-07-22 17:08:06,000 INFO HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-07-22 17:08:06,056 INFO HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-07-22 17:08:06,186 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-22 17:08:06,203 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# 2026-07-22 17:08:06,272 INFO HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2 "HTTP/1.1 200 OK"
# 2026-07-22 17:08:06,290 INFO Skip NUE 2026Q1 (already summarized)
# 2026-07-22 17:08:06,290 INFO Processing STLD 2026Q1
# C:\Users\trica\OneDrive\Documents\GitHub Repos\steel_financials\steel-dashboard\core\sec_pipeline\parse.py:29: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(html, "lxml")
# Batches: 100%|██████████| 4/4 [00:03<00:00,  1.23it/s]
# Batches: 100%|██████████| 4/4 [00:03<00:00,  1.27it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.55it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
# Batches: 100%|██████████| 3/3 [00:02<00:00,  1.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.39it/s]
# 2026-07-22 17:10:23,053 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-07-22 17:10:23,079 INFO Processing CLF 2026Q1
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.53it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.37it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  4.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 10.34it/s]
# 2026-07-22 17:11:25,470 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-07-22 17:11:25,507 INFO Processing CMC 2026Q1
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 15.69it/s]
# 2026-07-22 17:14:01,636 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-07-22 17:14:01,660 INFO Processing X 2026Q1
# 2026-07-22 17:14:01,690 WARNING No filings found for X 2026Q1
# 2026-07-22 17:14:01,690 INFO Processing ATI 2026Q1
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.47it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s]
# Batches: 100%|██████████| 3/3 [00:02<00:00,  1.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.57it/s]
# 2026-07-22 17:16:22,852 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-07-22 17:16:22,869 INFO Processing CRS 2026Q1
# Batches: 100%|██████████| 4/4 [00:03<00:00,  1.33it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.34it/s]
# Batches: 100%|██████████| 4/4 [00:02<00:00,  1.47it/s]
# Batches: 100%|██████████| 3/3 [00:02<00:00,  1.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 16.20it/s]
# 2026-07-22 17:17:07,566 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Airlines summarized: ['NUE', 'STLD', 'CLF', 'CMC', 'X', 'ATI', 'CRS']

# %%
# Preview one generated summary.
from IPython.display import Markdown

Markdown(summaries["NUE"]["2019"]["FY"])
# Out:
# ### Financial Insights
# 1. **Net earnings decreased significantly.** Nucor reported net earnings of \$1.27 billion, or \$4.14 per diluted share, in 2019, a sharp decline from \$2.36 billion, or \$7.42 per diluted share, in 2018. This reflects a decrease in net earnings attributable to Nucor stockholders as a percentage of net sales from 9.4% in 2018 to 5.6% in 2019.
#
# 2. **Total net sales fell by 10%.** Nucor's total net sales to external customers were \$22.59 billion in 2019, down from \$25.07 billion in 2018, primarily due to a 14% decrease in the steel mills segment and an 18% decline in the raw materials segment.
#
# 3. **Return on equity halved.** The return on average stockholders' equity dropped to 12.6% in 2019 from 25.5% in 2018, indicating a significant reduction in profitability relative to equity.
#
# 4. **Dividends increased for the 47th consecutive year.** Nucor paid a total dividend of \$1.60 per share in 2019, up from \$1.52 per share in 2018, demonstrating the company's commitment to returning capital to shareholders despite lower earnings.
#
# ### Operations Insights
# 5. **Capital expenditures surged.** Nucor's capital expenditures for 2019 were projected to be approximately \$1.50 billion, a significant increase from \$997.3 million in 2018, driven by major expansion projects including the hot band galvanizing line at Nucor Steel Arkansas and the sheet mill expansion at Nucor Steel Gallatin.
#
# 6. **Joint ventures expanded.** Nucor continued to invest in joint ventures, including a 50% interest in Nucor-JFE, which is building a galvanized sheet steel plant in central Mexico. This facility was expected to begin operations in the second half of 2019, enhancing Nucor's capacity in the automotive market.
#
# ### Commercial Strategy Insights
# 7. **Focus on value-added products.** Nucor's strategy to shift towards more value-added steel mill products is aimed at improving margins and reducing vulnerability to imports. This strategic pivot is part of a broader effort to enhance operational flexibility and market presence.
#
# 8. **Strong liquidity position maintained.** Nucor reported cash and cash equivalents of \$1.68 billion as of September 28, 2019, providing a solid foundation for capital deployment and operational flexibility amidst challenging market conditions.
#
# ### Executive and Personnel Changes Insights
# 9. **Leadership transition occurred.** On September 5, 2019, John J. Ferriola announced his retirement as Chairman and CEO, with Leon J. Topalian appointed as his successor effective January 1, 2020. This leadership change is part of Nucor's planned succession process.
#
# 10. **Retirement of key executive.** R. Joseph Stratman, Chief Digital Officer and Executive Vice President, announced his retirement effective June 8, 2019. MaryEmily Slate was promoted to Executive Vice President, reflecting ongoing adjustments in the executive team to align with strategic goals.
#
# ### Wrap Up
# In 2019, Nucor Corporation faced significant challenges, reflected in a sharp decline in net earnings and total sales, primarily due to reduced demand and pricing pressures in the steel industry. However, the company maintained a strong commitment to shareholder returns through increased dividends and a robust capital expenditure program aimed at expanding its operational capabilities. The leadership transition and strategic focus on value-added products indicate a proactive approach to navigating market headwinds. Looking forward, while Nucor's financial performance has been adversely affected, its strong liquidity and strategic investments position it for potential recovery.
